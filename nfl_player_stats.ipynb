# %%
import pandas as pd
from sqlalchemy import create_engine
from config import pswd

# %%
url = 'https://www.pro-football-reference.com/years/2019/scrimmage.htm'

# %%
tables = pd.read_html(url, header=[1])
stats2019 = tables[0]
stats2019['Player'] = stats2019['Player'].map(lambda x: x.rstrip('+*'))
stats2019
# Out:
#       Rk               Player   Tm Age    Pos   G  GS  Tgt  Rec   Yds  ...  \
# 0      1  Christian McCaffrey  CAR  23     RB  16  16  142  116  1005  ...
# 1      2      Ezekiel Elliott  DAL  24     RB  16  16   71   54   420  ...
# 2      3           Nick Chubb  CLE  24     RB  16  16   49   36   278  ...
# 3      4        Derrick Henry  TEN  25     RB  15  15   24   18   206  ...
# 4      5       Michael Thomas  NOR  26     WR  16  15  185  149  1725  ...
# ..   ...                  ...  ...  ..    ...  ..  ..  ...  ...   ...  ...
# 569  552        Jason Sanders  MIA  24      K  16   0    1    1     1  ...
# 570  553     Darrius Shepherd  GNB  24    NaN   6   0    2    1     1  ...
# 571  554       Eric Tomlinson  3TM  27    NaN   8   3    1    1     1  ...
# 572  555             Vita Vea  TAM  24  DL/dt  16  16    1    1     1  ...
# 573  556    Christian Wilkins  MIA  24     DT  16  14    1    1     1  ...
#
#     1D.1 Lng.1   Y/A  Y/G.1   A/G Touch Y/Tch  YScm RRTD Fmb
# 0     57    84   4.8   86.7  17.9   403   5.9  2392   19   1
# 1     78    33   4.5   84.8  18.8   355   5.0  1777   14   3
# 2     62    88   5.0   93.4  18.6   334   5.3  1772    8   3
# 3     73    74   5.1  102.7  20.2   321   5.4  1746   18   5
# 4      0    -9  -9.0   -0.6   0.1   150  11.4  1716    9   1
# ..   ...   ...   ...    ...   ...   ...   ...   ...  ...  ..
# 569    0   NaN   NaN    NaN   NaN     1   1.0     1    1   0
# 570    0   NaN   NaN    NaN   NaN     1   1.0     1    0   1
# 571    0   NaN   NaN    NaN   NaN     1   1.0     1    0   0
# 572    0   NaN   NaN    NaN   NaN     1   1.0     1    1   0
# 573    0   NaN   NaN    NaN   NaN     1   1.0     1    1   1
#
# [574 rows x 31 columns]

# %%
stats2019 = stats2019.replace({'TAM':'TB', 'OAK': 'LV', 'NOR': 'NO', 'SFO': 'SF', 
                                'GNB': 'GB', 'KAN': 'KC', 'NWE': 'NE'})
stats2019
# Out:
#       Rk               Player   Tm Age    Pos   G  GS  Tgt  Rec   Yds  ...  \
# 0      1  Christian McCaffrey  CAR  23     RB  16  16  142  116  1005  ...
# 1      2      Ezekiel Elliott  DAL  24     RB  16  16   71   54   420  ...
# 2      3           Nick Chubb  CLE  24     RB  16  16   49   36   278  ...
# 3      4        Derrick Henry  TEN  25     RB  15  15   24   18   206  ...
# 4      5       Michael Thomas   NO  26     WR  16  15  185  149  1725  ...
# ..   ...                  ...  ...  ..    ...  ..  ..  ...  ...   ...  ...
# 569  552        Jason Sanders  MIA  24      K  16   0    1    1     1  ...
# 570  553     Darrius Shepherd   GB  24    NaN   6   0    2    1     1  ...
# 571  554       Eric Tomlinson  3TM  27    NaN   8   3    1    1     1  ...
# 572  555             Vita Vea   TB  24  DL/dt  16  16    1    1     1  ...
# 573  556    Christian Wilkins  MIA  24     DT  16  14    1    1     1  ...
#
#     1D.1 Lng.1   Y/A  Y/G.1   A/G Touch Y/Tch  YScm RRTD Fmb
# 0     57    84   4.8   86.7  17.9   403   5.9  2392   19   1
# 1     78    33   4.5   84.8  18.8   355   5.0  1777   14   3
# 2     62    88   5.0   93.4  18.6   334   5.3  1772    8   3
# 3     73    74   5.1  102.7  20.2   321   5.4  1746   18   5
# 4      0    -9  -9.0   -0.6   0.1   150  11.4  1716    9   1
# ..   ...   ...   ...    ...   ...   ...   ...   ...  ...  ..
# 569    0   NaN   NaN    NaN   NaN     1   1.0     1    1   0
# 570    0   NaN   NaN    NaN   NaN     1   1.0     1    0   1
# 571    0   NaN   NaN    NaN   NaN     1   1.0     1    0   0
# 572    0   NaN   NaN    NaN   NaN     1   1.0     1    1   0
# 573    0   NaN   NaN    NaN   NaN     1   1.0     1    1   1
#
# [574 rows x 31 columns]

# %%
stats2019 = stats2019[['Player', 'Tm', 'Age', 'Pos', 'G', 'Touch', 'Y/Tch', 'YScm', 'RRTD', 'Fmb', 'Rec']]

stats2019
# Out:
#                   Player   Tm Age    Pos   G Touch Y/Tch  YScm RRTD Fmb  Rec
# 0    Christian McCaffrey  CAR  23     RB  16   403   5.9  2392   19   1  116
# 1        Ezekiel Elliott  DAL  24     RB  16   355   5.0  1777   14   3   54
# 2             Nick Chubb  CLE  24     RB  16   334   5.3  1772    8   3   36
# 3          Derrick Henry  TEN  25     RB  15   321   5.4  1746   18   5   18
# 4         Michael Thomas   NO  26     WR  16   150  11.4  1716    9   1  149
# ..                   ...  ...  ..    ...  ..   ...   ...   ...  ...  ..  ...
# 569        Jason Sanders  MIA  24      K  16     1   1.0     1    1   0    1
# 570     Darrius Shepherd   GB  24    NaN   6     1   1.0     1    0   1    1
# 571       Eric Tomlinson  3TM  27    NaN   8     1   1.0     1    0   0    1
# 572             Vita Vea   TB  24  DL/dt  16     1   1.0     1    1   0    1
# 573    Christian Wilkins  MIA  24     DT  16     1   1.0     1    1   1    1
#
# [574 rows x 11 columns]

# %%
stats2019 = stats2019.rename(columns={'Tm':'Team', 'Pos': 'Position', 'G': 'Games', 'Y/Tch': 'Yards/Touch', 
                                'YScm': 'Total_Yards', 'RRTD': 'Touchdowns', 'Fmb': 'Fumbles', 'Rec':'Receptions', 'Touch': 'Touches'})

stats2019
# Out:
#                   Player Team Age Position Games Touches Yards/Touch  \
# 0    Christian McCaffrey  CAR  23       RB    16     403         5.9
# 1        Ezekiel Elliott  DAL  24       RB    16     355         5.0
# 2             Nick Chubb  CLE  24       RB    16     334         5.3
# 3          Derrick Henry  TEN  25       RB    15     321         5.4
# 4         Michael Thomas   NO  26       WR    16     150        11.4
# ..                   ...  ...  ..      ...   ...     ...         ...
# 569        Jason Sanders  MIA  24        K    16       1         1.0
# 570     Darrius Shepherd   GB  24      NaN     6       1         1.0
# 571       Eric Tomlinson  3TM  27      NaN     8       1         1.0
# 572             Vita Vea   TB  24    DL/dt    16       1         1.0
# 573    Christian Wilkins  MIA  24       DT    16       1         1.0
#
#     Total_Yards Touchdowns Fumbles Receptions
# 0          2392         19       1        116
# 1          1777         14       3         54
# 2          1772          8       3         36
# 3          1746         18       5         18
# 4          1716          9       1        149
# ..          ...        ...     ...        ...
# 569           1          1       0          1
# 570           1          0       1          1
# 571           1          0       0          1
# 572           1          1       0          1
# 573           1          1       1          1
#
# [574 rows x 11 columns]

# %%
stats2019 = stats2019.loc[stats2019['Total_Yards'] != 'YScm']

stats2019
# Out:
#                   Player Team Age Position Games Touches Yards/Touch  \
# 0    Christian McCaffrey  CAR  23       RB    16     403         5.9
# 1        Ezekiel Elliott  DAL  24       RB    16     355         5.0
# 2             Nick Chubb  CLE  24       RB    16     334         5.3
# 3          Derrick Henry  TEN  25       RB    15     321         5.4
# 4         Michael Thomas   NO  26       WR    16     150        11.4
# ..                   ...  ...  ..      ...   ...     ...         ...
# 569        Jason Sanders  MIA  24        K    16       1         1.0
# 570     Darrius Shepherd   GB  24      NaN     6       1         1.0
# 571       Eric Tomlinson  3TM  27      NaN     8       1         1.0
# 572             Vita Vea   TB  24    DL/dt    16       1         1.0
# 573    Christian Wilkins  MIA  24       DT    16       1         1.0
#
#     Total_Yards Touchdowns Fumbles Receptions
# 0          2392         19       1        116
# 1          1777         14       3         54
# 2          1772          8       3         36
# 3          1746         18       5         18
# 4          1716          9       1        149
# ..          ...        ...     ...        ...
# 569           1          1       0          1
# 570           1          0       1          1
# 571           1          0       0          1
# 572           1          1       0          1
# 573           1          1       1          1
#
# [556 rows x 11 columns]

# %%
connection_string = f"postgres:{pswd}@localhost:5432/NFL_Draft"
engine = create_engine(f'postgresql://{connection_string}')

engine.table_names()
# Out:
# ['player_stats']

# %%
stats2019.to_sql(name='player_stats', con=engine, if_exists='append', index=False)
