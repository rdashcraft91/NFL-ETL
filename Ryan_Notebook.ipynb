# %% [markdown]
# # NFL Players by Draft Position

# %%
import pandas as pd
import requests

# %%
url = 'http://www.drafthistory.com/index.php/years/2019'

# %%
request = requests.get(url)
d2019 = pd.read_html(r.text, header=1)
d2019 = d2019[0]
# d2019 = d2019.iloc[1:]
d2019
# Out:
#      Round  Pick  Player              Name        Team Position  \
# 0      1.0     1       1      Kyler Murray   Cardinals       QB
# 1      NaN     2       2         Nick Bosa       49ers       DE
# 2      NaN     3       3  Quinnen Williams        Jets       DT
# 3      NaN     4       4    Clelin Ferrell     Raiders       DE
# 4      NaN     5       5       Devin White  Buccaneers       LB
# ..     ...   ...     ...               ...         ...      ...
# 249    NaN    36     250    Austin Cutting     Vikings        C
# 250    NaN    37     251      Dakota Allen        Rams       LB
# 251    NaN    38     252       Ken Webster    Patriots       DB
# 252    NaN    39     253  Jordan Brailford    Redskins       LB
# 253    NaN    40     254      Caleb Wilson   Cardinals       TE
#
#              College
# 0           Oklahoma
# 1         Ohio State
# 2            Alabama
# 3            Clemson
# 4    Louisiana State
# ..               ...
# 249        Air Force
# ...

# %%
# Out:
#       2019 - Round 1                                                   \
#               PLAYER POSITION      SCHOOL SEL #                  TEAM
# 0       Kyler Murray       QB    Oklahoma   1.0     Arizona Cardinals
# 1          Nick Bosa       DE  Ohio State   2.0   San Francisco 49ers
# 2   Quinnen Williams       DT     Alabama   3.0         New York Jets
# 3     Clelin Ferrell       DE     Clemson   4.0       Oakland Raiders
# 4        Devin White       LB         LSU   5.0  Tampa Bay Buccaneers
# ..               ...      ...         ...   ...                   ...
# 27               NaN      NaN         NaN   NaN                   NaN
# 28               NaN      NaN         NaN   NaN                   NaN
# 29               NaN      NaN         NaN   NaN                   NaN
# 30               NaN      NaN         NaN   NaN                   NaN
# 31               NaN      NaN         NaN   NaN                   NaN
#
#     2019 - Round 2
# ...

# %%
draft2019
