# %% [markdown]
# # NFL Players by Draft Position

# %%
import pandas as pd
import requests
from sqlalchemy import create_engine

# %%
url = 'http://www.drafthistory.com/index.php/years/'

# %%
rounds = []
years = list(range(1998,2020))

for year in years:
    request = requests.get(f'{url}{year}')
    draft = pd.read_html(request.text, header=1)
    draft = draft[0]
    rounds.append(draft)

# %%
draft1998 = rounds[0]
draft1999 = rounds[1]
draft2000 = rounds[2] 
draft2001 = rounds[3] 
draft2002 = rounds[4]
draft2003 = rounds[5]
draft2004 = rounds[6]
draft2005 = rounds[7]
draft2006 = rounds[8]
draft2007 = rounds[9]
draft2008 = rounds[10] 
draft2009 = rounds[11] 
draft2010 = rounds[12]
draft2011 = rounds[13]
draft2012 = rounds[14]
draft2013 = rounds[15]
draft2014 = rounds[16]
draft2015 = rounds[17]
draft2016 = rounds[18]
draft2017 = rounds[19]
draft2018 = rounds[20]
draft2019 = rounds[21]

# %%
draft1998['Year'] = '1998'
draft1999['Year'] = '1999'
draft2000['Year'] = '2000' 
draft2001['Year'] = '2001' 
draft2002['Year'] = '2002'
draft2003['Year'] = '2003'
draft2004['Year'] = '2004'
draft2005['Year'] = '2005'
draft2006['Year'] = '2006'
draft2007['Year'] = '2007'
draft2008['Year'] = '2008'
draft2009['Year'] = '2009'
draft2010['Year'] = '2010'
draft2011['Year'] = '2011'
draft2012['Year'] = '2012'
draft2013['Year'] = '2013'
draft2014['Year'] = '2014'
draft2015['Year'] = '2015'
draft2016['Year'] = '2016'
draft2017['Year'] = '2017'
draft2018['Year'] = '2018'
draft2019['Year'] = '2019'

# %%
all_drafts = [draft1998, draft1999, draft2000, draft2001, draft2002, draft2003, draft2004, draft2005, draft2006, 
              draft2007, draft2008, draft2009, draft2010, draft2011, draft2012, draft2013, draft2014, draft2015, 
              draft2016, draft2017, draft2018, draft2019]

all_drafts = pd.concat(all_drafts).reset_index(drop=True)

all_drafts.head(50)
# Out:
#     Round  Pick  Player               Name        Team Position  \
# 0     1.0     1       1     Peyton Manning       Colts       QB
# 1     NaN     2       2          Ryan Leaf    Chargers       QB
# 2     NaN     3       3    Andre Wadsworth   Cardinals       DE
# 3     NaN     4       4    Charles Woodson     Raiders       DB
# 4     NaN     5       5        Curtis Enis       Bears       RB
# 5     NaN     6       6      Grant Wistrom        Rams       DE
# 6     NaN     7       7        Kyle Turley      Saints        T
# 7     NaN     8       8         Greg Ellis     Cowboys       DE
# 8     NaN     9       9        Fred Taylor     Jaguars       RB
# 9     NaN    10      10       Duane Starks      Ravens       DB
# 10    NaN    11      11         Tra Thomas      Eagles        T
# 11    NaN    12      12     Keith Brooking     Falcons       LB
# 12    NaN    13      13       Takeo Spikes     Bengals       LB
# 13    NaN    14      14        Jason Peter    Panthers       DT
# 14    NaN    15      15    Anthony Simmons    Seahawks       LB
# 15    NaN    16      16        Kevin Dyson      Oilers       WR
# 16    NaN    17      17      Brian Simmons     Bengals       LB
# 17    NaN    18      18     Robert Edwards    Patriots       RB
# 18    NaN    19      19    Vonnie Holliday     Packers       DT
# 19    NaN    20      20         Terry Fair       Lions       DB
# 20    NaN    21      21         Randy Moss     Vikings       WR
# 21    NaN    22      22      Tebucky Jones    Patriots       DB
# 22    NaN    23      23         Mo Collins     Raiders        T
# 23    NaN    24      24     Shaun Williams      Giants       DB
# 24    NaN    25      25     Donovin Darius     Jaguars       DB
# 25    NaN    26      26        Alan Faneca    Steelers        G
# 26    NaN    27      27       Victor Riley      Chiefs        T
# 27    NaN    28      28    R.W. McQuarters       49ers       DB
# 28    NaN    29      29         John Avery    Dolphins       RB
# 29    NaN    30      30        Marcus Nash     Broncos       WR
# 30    2.0     1      31        Leon Bender     Raiders       DT
# 31    NaN     2      32      Jerome Pathon       Colts       WR
# 32    NaN     3      33      Corey Chavous   Cardinals       DB
# 33    NaN     4      34      Jacquez Green  Buccaneers       WR
# 34    NaN     5      35       Tony Parrish       Bears       DB
# 35    NaN     6      36    Anthony Clement   Cardinals        T
# 36    NaN     7      37    Robert Holcombe        Rams       RB
# 37    NaN     8      38      Flozell Adams     Cowboys        T
# 38    NaN     9      39         Sam Cowart       Bills       LB
# 39    NaN    10      40   Cameron Cleeland      Saints       TE
# 40    NaN    11      41       Jeremy Staat    Steelers       DE
# 41    NaN    12      42    Patrick Johnson      Ravens       WR
# 42    NaN    13      43    Artrell Hawkins     Bengals       DB
# 43    NaN    14      44    Patrick Surtain    Dolphins       DB
# 44    NaN    15      45        Brian Kelly  Buccaneers       DB
# 45    NaN    16      46       Samari Rolle      Oilers       DB
# 46    NaN    17      47        Todd Weiner    Seahawks        T
# 47    NaN    18      48  Stephen Alexander    Redskins       TE
# 48    NaN    19      49        Kenny Mixon    Dolphins       DE
# 49    NaN    20      50    Germane Crowell       Lions       WR
#
#                    College  Year
# 0                Tennessee  1998
# 1         Washington State  1998
# 2            Florida State  1998
# 3                 Michigan  1998
# 4               Penn State  1998
# 5                 Nebraska  1998
# 6          San Diego State  1998
# 7           North Carolina  1998
# 8                  Florida  1998
# 9               Miami (FL)  1998
# 10           Florida State  1998
# 11            Georgia Tech  1998
# 12                  Auburn  1998
# 13                Nebraska  1998
# 14                 Clemson  1998
# 15                    Utah  1998
# 16          North Carolina  1998
# 17                 Georgia  1998
# 18          North Carolina  1998
# 19               Tennessee  1998
# 20                Marshall  1998
# 21                Syracuse  1998
# 22                 Florida  1998
# 23                    UCLA  1998
# 24                Syracuse  1998
# 25         Louisiana State  1998
# 26                  Auburn  1998
# 27          Oklahoma State  1998
# 28             Mississippi  1998
# 29               Tennessee  1998
# 30        Washington State  1998
# 31              Washington  1998
# 32              Vanderbilt  1998
# 33                 Florida  1998
# 34              Washington  1998
# 35  Southwestern Louisiana  1998
# 36                Illinois  1998
# 37          Michigan State  1998
# 38           Florida State  1998
# 39              Washington  1998
# 40           Arizona State  1998
# 41                  Oregon  1998
# 42              Cincinnati  1998
# 43    Southern Mississippi  1998
# 44                     USC  1998
# 45           Florida State  1998
# 46            Kansas State  1998
# 47                Oklahoma  1998
# 48         Louisiana State  1998
# 49                Virginia  1998

# %%
all_drafts['Round'] = all_drafts['Round'].fillna(method='ffill')

all_drafts = all_drafts.rename(columns={"Pick": "Round_Pick", "Player": "Overall_Pick"})

all_drafts['Name'].value_counts()
# Out:
# Brian Allen             4
# Brandon Williams        4
# Mike Williams           4
# Steve Smith             3
# Chris Jones             3
#                        ..
# Crezdon Butler          1
# Nathan Peterman         1
# Eric Hagg               1
# Ras-I Dowling           1
# Kabeer Gbaja-Biamila    1
# Name: Name, Length: 5508, dtype: int64

# %%
connection_string = "postgres:R4$hcr4ft13@localhost:5432/NFL_Draft"
engine = create_engine(f'postgresql://{connection_string}')

engine.table_names()
# Out:
# ['drafts']

# %%
all_drafts.to_sql(name='drafts', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UniqueViolation: duplicate key value violates unique constraint "drafts_pkey"
# DETAIL:  Key ("Name")=(Chris Akins) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-14-4b8551524736> in <module>
# ----> 1 all_drafts.to_sql(name='drafts', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "drafts_pkey"
# DETAIL:  Key ("Name")=(Chris Akins) already exists.
#
# [SQL: INSERT INTO drafts ("Round", "Round_Pick", "Overall_Pick", "Name", "Team", "Position", "College", "Year") VALUES (%(Round)s, %(Round_Pick)s, %(Overall_Pick)s, %(Name)s, %(Team)s, %(Position)s, %(College)s, %(Year)s)]
# [parameters: ({'Round': 1.0, 'Round_Pick': 1, 'Overall_Pick': 1, 'Name': 'Peyton Manning', 'Team': 'Colts', 'Position': 'QB', 'College': 'Tennessee', 'Year': '1998'}, {'Round': 1.0, 'Round_Pick': 2, 'Overall_Pick': 2, 'Name': 'Ryan Leaf', 'Team': 'Chargers', 'Position': 'QB', 'College': 'Washington State', 'Year': '1998'}, {'Round': 1.0, 'Round_Pick': 3, 'Overall_Pick': 3, 'Name': 'Andre Wadsworth', 'Team': 'Cardinals', 'Position': 'DE', 'College': 'Florida State', 'Year': '1998'}, {'Round': 1.0, 'Round_Pick': 4, 'Overall_Pick': 4, 'Name': 'Charles Woodson', 'Team': 'Raiders', 'Position': 'DB', 'College': 'Michigan', 'Year': '1998'}, {'Round': 1.0, 'Round_Pick': 5, 'Overall_Pick': 5, 'Name': 'Curtis Enis', 'Team': 'Bears', 'Position': 'RB', 'College': 'Penn State', 'Year': '1998'}, {'Round': 1.0, 'Round_Pick': 6, 'Overall_Pick': 6, 'Name': 'Grant Wistrom', 'Team': 'Rams', 'Position': 'DE', 'College': 'Nebraska', 'Year': '1998'}, {'Round': 1.0, 'Round_Pick': 7, 'Overall_Pick': 7, 'Name': 'Kyle Turley', 'Team': 'Saints', 'Position': 'T', 'College': 'San Diego State', 'Year': '1998'}, {'Round': 1.0, 'Round_Pick': 8, 'Overall_Pick': 8, 'Name': 'Greg Ellis', 'Team': 'Cowboys', 'Position': 'DE', 'College': 'North Carolina', 'Year': '1998'}  ... displaying 10 of 5589 total bound parameter sets ...  {'Round': 7.0, 'Round_Pick': 39, 'Overall_Pick': 253, 'Name': 'Jordan Brailford', 'Team': 'Redskins', 'Position': 'LB', 'College': 'Oklahoma State', 'Year': '2019'}, {'Round': 7.0, 'Round_Pick': 40, 'Overall_Pick': 254, 'Name': 'Caleb Wilson', 'Team': 'Cardinals', 'Position': 'TE', 'College': 'UCLA', 'Year': '2019'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)
